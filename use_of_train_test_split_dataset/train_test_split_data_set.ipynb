# %%
#import liberray
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic") # load dataset

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2=df[["survived","pclass","age","sibsp","parch","fare"]]
df2
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df3=df2.fillna(df2.mean())

# %%
df3
# Out:
#      survived  pclass        age  sibsp  parch     fare
# 0           0       3  22.000000      1      0   7.2500
# 1           1       1  38.000000      1      0  71.2833
# 2           1       3  26.000000      0      0   7.9250
# 3           1       1  35.000000      1      0  53.1000
# 4           0       3  35.000000      0      0   8.0500
# ..        ...     ...        ...    ...    ...      ...
# 886         0       2  27.000000      0      0  13.0000
# 887         1       1  19.000000      0      0  30.0000
# 888         0       3  29.699118      1      2  23.4500
# 889         1       1  26.000000      0      0  30.0000
# 890         0       3  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
# survived is a dependent variable
# pclass,age,sibsp,parch,fare are independent variable
# drop sur
x=df3.drop("survived",axis=1)
y=df3["survived"]

# %%
x.shape
y.shape
# Out:
# (891,)

# %%
from sklearn.model_selection import train_test_split # impoert train_test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=51)  # data split
print("shape of x_train",x_train.shape)
print("shape of x_test",x_test.shape)
print("shape of y_train",y_train.shape)
print("shape of y_test",y_test.shape)
# Out:
# shape of x_train (623, 5)
# shape of x_test (268, 5)
# shape of y_train (623,)
# shape of y_test (268,)

# %%
x_train.head()
# Out:
#      pclass        age  sibsp  parch     fare
# 584       3  29.699118      0      0   8.7125
# 643       3  29.699118      0      0  56.4958
# 817       2  31.000000      1      1  37.0042
# 672       2  70.000000      0      0  10.5000
# 404       3  20.000000      0      0   8.6625

# %%
x_train.shape
# Out:
# (623, 5)

# %%
x_train.describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  623.000000  623.000000  623.000000  623.000000  623.000000
# mean     2.287319   29.500212    0.555377    0.399679   32.263429
# std      0.846375   13.027507    1.139639    0.817297   48.646755
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      1.000000   22.000000    0.000000    0.000000    7.925000
# 50%      3.000000   29.699118    0.000000    0.000000   14.500000
# 75%      3.000000   35.000000    1.000000    0.000000   31.275000
# max      3.000000   71.000000    8.000000    5.000000  512.329200
